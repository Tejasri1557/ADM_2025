# %% [markdown]
# <a href="https://colab.research.google.com/github/Tejasri1557/ADM_2025/blob/main/2303a51557_ASSN_05_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/tweets.csv.zip")

# %%
from sklearn.model_selection import StratifiedKFold, cross_validate, cross_val_predict
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
x=df["text"]
y=df["target"]

# %%
print(x)
print(y)
# Out:
# 0        Communal violence in Bhainsa, Telangana. "Ston...
# 1        Telangana: Section 144 has been imposed in Bha...
# 2        Arsonist sets cars ablaze at dealership https:...
# 3        Arsonist sets cars ablaze at dealership https:...
# 4        "Lord Jesus, your love brings freedom and pard...
#                                ...
# 11365    Media should have warned us well in advance. T...
# 11366    i feel directly attacked 💀 i consider moonbin ...
# 11367    i feel directly attacked 💀 i consider moonbin ...
# 11368    ok who remember "outcast" nd the "dora" au?? T...
# 11369       Jake Corway wrecked while running 14th at IRP.
# Name: text, Length: 11370, dtype: object
# 0        1
# 1        1
# 2        1
# 3        1
# 4        0
#         ..
# 11365    0
# 11366    0
# 11367    0
# 11368    0
# 11369    1
# Name: target, Length: 11370, dtype: int64

# %%
tf=TfidfVectorizer(max_features=5000,ngram_range=(1,2),min_df=2)
abc=tf.fit_transform(x)

# %%
print(abc)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 186796 stored elements and shape (11370, 5000)>
#   Coords	Values
#   (0, 4586)	0.23052231727855163
#   (0, 2010)	0.07905699915294268
#   (0, 563)	0.257085994205112
#   (0, 3876)	0.25286916085472383
#   (0, 3753)	0.26460385566894246
#   (0, 4727)	0.3167239966644266
#   (0, 2918)	0.10442790110695098
#   (0, 2676)	0.24268510801285312
#   (0, 1936)	0.46104463455710326
#   (0, 250)	0.16305144757960063
#   (0, 3669)	0.1639574836751449
#   (0, 4558)	0.24912189183861053
#   (0, 3541)	0.20197626297639754
#   (0, 81)	0.23728305259646668
#   (0, 2020)	0.274296064803298
#   (0, 289)	0.26460385566894246
#   (1, 2010)	0.07189292865746016
#   (1, 563)	0.23378910454802368
#   (1, 3876)	0.22995439664779885
#   (1, 2918)	0.09496474347079846
#   (1, 2020)	0.24943961482493926
#   (1, 3496)	0.2530482133842609
#   (1, 1764)	0.12036460571977645
#   (1, 532)	0.13097718051877863
#   (1, 1614)	0.11082860378080091
#   :	:
# ...

# %%
tf=TfidfVectorizer(max_features=10000,ngram_range=(1,2),min_df=2)
xx=tf.fit_transform(x)

# %%
print(xx)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 211331 stored elements and shape (11370, 10000)>
#   Coords	Values
#   (0, 1927)	0.26274099162864895
#   (0, 9191)	0.20594310389972487
#   (0, 3991)	0.07062762505064311
#   (0, 1153)	0.22967445512779247
#   (0, 7926)	0.22590723744987257
#   (0, 7710)	0.23639073207150607
#   (0, 9459)	0.2829536147416951
#   (0, 6289)	0.26274099162864895
#   (0, 5991)	0.09329337975425596
#   (0, 5482)	0.216809049138676
#   (0, 3855)	0.41188620779944973
#   (0, 510)	0.1456662487446309
#   (0, 7560)	0.14647567964036545
#   (0, 9136)	0.2225595172749399
#   (0, 7358)	0.18044074431702126
#   (0, 194)	0.21198298252168707
#   (0, 4014)	0.24504951902254354
#   (0, 580)	0.23639073207150607
#   (0, 7359)	0.2526136959406965
#   (1, 3991)	0.06954794898366198
#   (1, 1153)	0.22616344916913816
#   (1, 7926)	0.22245382049782925
#   (1, 5991)	0.09186721500276918
#   (1, 4014)	0.24130347629883356
#   (1, 7276)	0.24479437078863786
#   :	:
# ...

# %%
tf=TfidfVectorizer(max_features=20000,ngram_range=(1,2),min_df=2)
yy=tf.fit_transform(x)

# %%
print(yy)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 238066 stored elements and shape (11370, 20000)>
#   Coords	Values
#   (0, 4041)	0.2455186159117438
#   (0, 18795)	0.1924437656743455
#   (0, 7438)	0.06599806387301739
#   (0, 1996)	0.21461955359047558
#   (0, 16632)	0.21109927278317617
#   (0, 16242)	0.2208955861542528
#   (0, 19190)	0.2644063243728384
#   (0, 13901)	0.2455186159117438
#   (0, 13380)	0.08717810391523263
#   (0, 11633)	0.20259746045605156
#   (0, 7253)	0.384887531348691
#   (0, 857)	0.13611799040244596
#   (0, 15931)	0.13687436401573363
#   (0, 18709)	0.20797099189059665
#   (0, 15520)	0.16861305700411813
#   (0, 314)	0.19808773706361008
#   (0, 4042)	0.2517946484755211
#   (0, 18797)	0.2517946484755211
#   (0, 7470)	0.2289867993848783
#   (0, 1008)	0.2208955861542528
#   (0, 15521)	0.2360551530359192
#   (1, 7438)	0.06722184096364292
#   (1, 1996)	0.21859916264976015
#   (1, 16632)	0.21501360660934435
#   (1, 13380)	0.08879461446288904
#   :	:
# ...

# %%
print("Dataset size:", abc.shape)
print("Dataset size:", xx.shape)
print("Dataset size:", yy.shape)
# Out:
# Dataset size: (11370, 5000)
# Dataset size: (11370, 10000)
# Dataset size: (11370, 20000)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(abc,y,test_size=0.25,random_state=42)
Y_train, Y_test, y_train, y_test = train_test_split(xx,y,test_size=0.25, random_state=42)
Z_train, Z_test, y_train, y_test = train_test_split(yy, y, test_size=0.25, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lg=LogisticRegression()
model=lg.fit(X_train,y_train)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
y_pred=model.predict(X_test)
accuracy=accuracy_score(y_test,y_pred)
print("Accuracy:",accuracy)
# Out:
# Accuracy: 0.8793527963418923

# %%
lg=LogisticRegression()
model=lg.fit(X_train,y_train)

# %%
class_report=classification_report(y_test,y_pred)
print("Classification Report:\n",class_report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.98      0.93      2345
#            1       0.84      0.39      0.53       498
#
#     accuracy                           0.88      2843
#    macro avg       0.86      0.68      0.73      2843
# weighted avg       0.88      0.88      0.86      2843

# %%
cc=confusion_matrix(y_test,y_pred)
print("Confusion Matrix:\n",cc)
# Out:
# Confusion Matrix:
#  [[2308   37]
#  [ 306  192]]
